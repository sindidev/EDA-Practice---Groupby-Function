# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
df.head()
# Out:
#    Year       Product line  Product type              Product  \
# 0  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4  2004  Camping Equipment  Cooking Gear  TrailChef Water Bag
#
#   Order method type Retailer country    Revenue  Planned revenue  \
# 0         Telephone    United States  315044.33        437477.15
# 1         Telephone           Canada   13444.68         14313.48
# 2         Telephone           Mexico        NaN              NaN
# 3         Telephone           Brazil        NaN              NaN
# 4         Telephone            Japan  181120.24        235236.64
#
#    Product cost  Quantity  Unit cost  Unit price  Gross profit  \
# 0     158371.76   66385.0   2.552857        6.59     156672.57
# 1       6298.80    2172.0   2.900000        6.59       7145.88
# ...

# %%
#how many rows and columns
print(df.shape)
# Out:
# (84672, 14)

# %%
#print column names
print(df.columns)
# Out:
# Index(['Year', 'Product line', 'Product type', 'Product', 'Order method type',
#        'Retailer country', 'Revenue', 'Planned revenue', 'Product cost',
#        'Quantity', 'Unit cost', 'Unit price', 'Gross profit',
#        'Unit sale price'],
#       dtype='object')

# %%
#print general info about the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84672 entries, 0 to 84671
# Data columns (total 14 columns):
# Year                 84672 non-null int64
# Product line         84672 non-null object
# Product type         84672 non-null object
# Product              84672 non-null object
# Order method type    84672 non-null object
# Retailer country     84672 non-null object
# Revenue              24743 non-null float64
# Planned revenue      24743 non-null float64
# Product cost         24743 non-null float64
# Quantity             24743 non-null float64
# Unit cost            24743 non-null float64
# Unit price           24743 non-null float64
# Gross profit         24743 non-null float64
# Unit sale price      24743 non-null float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 9.0+ MB
# None

# %%
#describe the statistical characteristics of each numerical feature
df.describe()
# Out:
#                Year       Revenue  Planned revenue  Product cost  \
# count  84672.000000  2.474300e+04     2.474300e+04  2.474300e+04
# mean    2005.500000  1.894183e+05     1.988175e+05  1.116251e+05
# std        1.118041  3.907509e+05     4.025355e+05  2.384156e+05
# min     2004.000000  0.000000e+00     1.569000e+01  5.760000e+00
# 25%     2004.750000  1.857921e+04     1.955679e+04  9.431740e+03
# 50%     2005.500000  5.986727e+04     6.390684e+04  3.278372e+04
# 75%     2006.250000  1.901930e+05     2.039956e+05  1.113709e+05
# max     2007.000000  1.005429e+07     1.005429e+07  6.756853e+06
#
#             Quantity     Unit cost    Unit price  Gross profit  \
# count   24743.000000  24743.000000  24743.000000  2.474300e+04
# mean     3606.559067     84.886432    155.991651  7.779311e+04
# std      8777.721091    131.113339    246.804787  1.581223e+05
# min         1.000000      0.850000      2.060000 -1.815960e+04
# ...

# %%
#describe the statistical characteristics of non-numerical features
df.describe(include=['object', 'bool'])
# Out:
#                 Product line Product type      Product Order method type  \
# count                  84672        84672        84672             84672
# unique                     5           21          144                 7
# top     Personal Accessories      Eyewear  Astro Pilot         Telephone
# freq                   30576         9408          588             12096
#
#        Retailer country
# count             84672
# unique               21
# top              Brazil
# freq               4032

# %%
import pandas as pd
df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
print(df.groupby('Product').size())
# Out:
# Product
# Aloe Relief                       588
# Astro Pilot                       588
# Auto Pilot                        588
# Bear Edge                         588
# Bear Survival Edge                588
# Bella                             588
# Blue Steel Max Putter             588
# Blue Steel Putter                 588
# BugShield Extreme                 588
# BugShield Lotion                  588
# BugShield Lotion Lite             588
# BugShield Natural                 588
# BugShield Spray                   588
# Calamine Relief                   588
# Canyon Mule Carryall              588
# Canyon Mule Climber Backpack      588
# Canyon Mule Cooler                588
# Canyon Mule Extreme Backpack      588
# Canyon Mule Journey Backpack      588
# Canyon Mule Weekender Backpack    588
# Capri                             588
# Cat Eye                           588
# Compact Relief Kit                588
# Course Pro Gloves                 588
# ...

# %%
print(df.groupby('Order method type').size())
# Out:
# Order method type
# E-mail         12096
# Fax            12096
# Mail           12096
# Sales visit    12096
# Special        12096
# Telephone      12096
# Web            12096
# dtype: int64

# %%
print(df.groupby('Retailer country').size())
# Out:
# Retailer country
# Australia         4032
# Austria           4032
# Belgium           4032
# Brazil            4032
# Canada            4032
# China             4032
# Denmark           4032
# Finland           4032
# France            4032
# Germany           4032
# Italy             4032
# Japan             4032
# Korea             4032
# Mexico            4032
# Netherlands       4032
# Singapore         4032
# Spain             4032
# Sweden            4032
# Switzerland       4032
# United Kingdom    4032
# United States     4032
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
print(df.groupby.hist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-a11633a6966e> in <module>
#       1 import pandas as pd
#       2 df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
# ----> 3 print(df.groupby.hist)
#
# AttributeError: 'function' object has no attribute 'hist'

# %% [raw]
# import pandas as pd
# df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
# print(df.groupby.all)

# %%
groupby.all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f29181214d5a> in <module>
# ----> 1 groupby.all
#
# NameError: name 'groupby' is not defined

# %%
import pandas as pd
df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
groupby.all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-634b1052674d> in <module>
#       1 import pandas as pd
#       2 df = pd.read_csv("c:/Users/Grace Newhart/Desktop/LearnIT Girl/IBMDataset.csv")
# ----> 3 groupby.all
#
# NameError: name 'groupby' is not defined

# %%
print(df.groupby()
# Out:
#   File "<ipython-input-6-072ef1ea26b4>", line 1
#     print(df.groupby()
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
print df.groupby
# Out:
#   File "<ipython-input-7-1853f594c814>", line 1
#     print df.groupby
#            ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(df.groupby)?

# %%
print(df.groupby)
# Out:
# <bound method NDFrame.groupby of        Year              Product line  Product type              Product  \
# 0      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 5      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 6      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 7      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 8      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 9      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 10     2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# ...

# %%
print(df.groupby).groups
# Out:
# <bound method NDFrame.groupby of        Year              Product line  Product type              Product  \
# 0      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 5      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 6      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 7      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 8      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 9      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 10     2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# ...

# %%
print(df.groupby).indices
# Out:
# <bound method NDFrame.groupby of        Year              Product line  Product type              Product  \
# 0      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 5      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 6      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 7      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 8      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 9      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 10     2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# ...

# %%
print(df.groupby(indices))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-12b65d45a007> in <module>
# ----> 1 print(df.groupby(indices))
#
# NameError: name 'indices' is not defined

# %%
print(df.groupby.agg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-1a647cc956c5> in <module>
# ----> 1 print(df.groupby.agg)
#
# AttributeError: 'function' object has no attribute 'agg'

# %%
print(df.groupby).agg
# Out:
# <bound method NDFrame.groupby of        Year              Product line  Product type              Product  \
# 0      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 5      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 6      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 7      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 8      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 9      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 10     2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# ...
